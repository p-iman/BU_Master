# %% [markdown]
# # Checking your setup
# Run through this notebook to make sure your environment is properly setup. Be sure to launch Jupyter from inside the virtual environment.

# %%
from check_environment import run_checks
run_checks()
# Out:
# Using Python in C:\Users\paula.iman\Documents\dsc530\envs\book_env:
# [ OK ] Python is version 3.8.20 (default, Oct  3 2024, 15:19:54) [MSC v.1929 64 bit (AMD64)]
#
# [FAIL] graphviz not installed.
# [FAIL] imblearn version 0.7.0 is required, but 0.12.3 installed.
# [FAIL] ipympl version 0.6.2 is required, but 0.9.3 installed.
# [FAIL] jupyterlab version >= 3.0.4 and <= 3.5.3 is required, but 4.2.5 installed.
# [FAIL] matplotlib version 3.3.2 is required, but 3.7.2 installed.
# [FAIL] numpy version >= 1.19.2 and <= 1.19.5 is required, but 1.24.3 installed.
# [FAIL] pandas version 1.2.0 is required, but 2.0.3 installed.
# [FAIL] requests version 2.24.0 is required, but 2.32.3 installed.
# [FAIL] sklearn version 0.23.2 is required, but 1.3.0 installed.
# [FAIL] scipy version >= 1.5.0 and <= 1.7.3 is required, but 1.10.1 installed.
# [FAIL] seaborn version >= 0.11.0 and <= 0.11.2 is required, but 0.13.2 installed.
# [FAIL] sqlalchemy version >= 1.3.19 and <= 1.3.20 is required, but 2.0.34 installed.
# [FAIL] statsmodels version >= 0.11.1 and <= 0.12.1 is required, but 0.14.1 installed.
# [ OK ] wheel
# [ OK ] login_attempt_simulator
# [ OK ] ml_utils
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from check_environment import run_checks
# ----> 2 run_checks()
#
# File ~\Documents\dsc530\envs\book_env\Hands-On-Data-Analysis-with-Pandas-2nd-edition-master\ch_01\check_environment.py:63, in run_checks(raise_exc)
#      61 for pkg, req_version in requirements.items():
#      62     try:
# ---> 63         mod = importlib.import_module(pkg)
#      64         if req_version:
#      65             version = mod.__version__
#
# File ~\Documents\dsc530\envs\book_env\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1014, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:975, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:671, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:843, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:219, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\Documents\dsc530\envs\book_env\lib\site-packages\stock_analysis\__init__.py:5
#       3 from .stock_analyzer import StockAnalyzer, AssetGroupAnalyzer
#       4 from .stock_modeler import StockModeler
# ----> 5 from .stock_reader import StockReader
#       6 from .stock_visualizer import StockVisualizer, AssetGroupVisualizer
#
# File ~\Documents\dsc530\envs\book_env\lib\site-packages\stock_analysis\stock_reader.py:8
#       6 import pandas as pd
#       7 import pandas_datareader.data as web
# ----> 8 import yfinance as yf
#      10 from .utils import label_sanitizer
#      13 class StockReader:
#
# File ~\Documents\dsc530\envs\book_env\lib\site-packages\yfinance\__init__.py:26
#      24 from .lookup import Lookup
#      25 from .ticker import Ticker
# ---> 26 from .tickers import Tickers
#      27 from .multi import download
#      28 from .live import WebSocket, AsyncWebSocket
#
# File ~\Documents\dsc530\envs\book_env\lib\site-packages\yfinance\tickers.py:26
#      22 from __future__ import print_function
#      24 import warnings
# ---> 26 from . import Ticker, multi
#      27 from .live import WebSocket
#      28 from .data import YfData
#
# File ~\Documents\dsc530\envs\book_env\lib\site-packages\yfinance\multi.py:30
#      27 from typing import Union
#      28 import warnings
# ---> 30 import multitasking as _multitasking
#      31 import pandas as _pd
#      32 from curl_cffi import requests
#
# File ~\Documents\dsc530\envs\book_env\lib\site-packages\multitasking\__init__.py:36
#      32 from threading import Thread, Semaphore
#      33 from multiprocessing import Process, cpu_count
# ---> 36 class PoolConfig(TypedDict):
#      37     """Type definition for execution pool configuration.
#      38
#      39     This defines the structure of each pool in the POOLS dictionary,
#      40     containing the semaphore for limiting concurrent tasks, the engine
#      41     type (Thread or Process), pool name, and thread count.
#      42     """
#      43     pool: Optional[Semaphore]  # Controls concurrent task execution
#
# File ~\Documents\dsc530\envs\book_env\lib\site-packages\multitasking\__init__.py:44, in PoolConfig()
#      37 """Type definition for execution pool configuration.
#      38
#      39 This defines the structure of each pool in the POOLS dictionary,
#      40 containing the semaphore for limiting concurrent tasks, the engine
#      41 type (Thread or Process), pool name, and thread count.
#      42 """
#      43 pool: Optional[Semaphore]  # Controls concurrent task execution
# ---> 44 engine: Union[type[Thread], type[Process]]  # Execution engine
#      45 name: str  # Human-readable pool identifier
#      46 threads: int
#
# TypeError: 'type' object is not subscriptable

# %% [markdown]
# *Note: Adapted from Andreas Mueller's [`check_env.ipynb` notebook](https://github.com/amueller/ml-workshop-1-of-4/blob/master/check_env.ipynb).*
#
# <hr>
# <div style="overflow: hidden; margin-bottom: 10px;">
#     <div style="float: left;">
#          <a href="./introduction_to_data_analysis.ipynb">
#             <button>&#8592; Introduction to Data Analysis</button>
#         </a>
#     </div>
#     <div style="float: right;">
#         <a href="./python_101.ipynb">
#             <button>Python 101</button>
#         </a>
#         <a href="./exercises.ipynb">
#             <button>Exercises &#8594;</button>
#         </a>
#     </div>
# </div>
# <hr>
