# %% [markdown]
# **My commentary in Markdown code chunk should be removed before you finalized your weekly assignment submission.**

# %% [markdown]
# -- Replace the following bullets with your information --
#
# *  Course Name
# *  Assignment Name
# *  Student Name

# %% [markdown]
# **Make sure you review the Chapter exercises numbers listed in Blackboard and be clear on how to solve each part of the problem in your submission.**

# %% [markdown]
# **Note. use #comment or markdown cell to clearly label each problem and parts. Access the [Markdown cheat sheet](https://www.markdownguide.org/cheat-sheet/) if you would like to learn more on how to use it.**

# %% [markdown]
# # Chapter X, Exercise X

# %% [markdown]
# You can add the Question text here if you would like. Otherwise, proceed to solve the problem with #comments or markdown to explain your steps.

# %% [markdown]
# (Example 1) Step-by-step coding by different code cells

# %% [markdown]
# **Note. The goal here is to show your solution and the output to confirm your codes worked!**

# %%
# 1a. Read in the aapl.csv, amzn.csv, fb.csv, goog.csv, and nflx.csv files.
a=1

# %%
# 1b. Add a column to each dataframe, called ticker, indicating the ticker symbol it is for (Apple's is AAPL, for example);
# this is how you look up a stock. In this case, the filenames happen to be the ticker symbols.
b=2

# %%
# 1c. Append them together into a single dataframe.
a+b
# Out:
# 3

# %%
# 1d. d) Save the result in a CSV file called faang.csv.
...

# %% [markdown]
# (Example 2) Step-by-step coding within the same code cell

# %%
# 1a) Read in the aapl.csv, amzn.csv, fb.csv, goog.csv, and nflx.csv files.
a=1
# 1b) Add a column to each dataframe, called ticker, indicating the ticker symbol it is for (Apple's is AAPL, for example); this is how you look up a stock. In this case, the filenames happen to be the ticker symbols.
b=2
# 1c) Append them together into a single dataframe.
a+b
# 1d) Save the result in a CSV file called faang.csv.
# Out:
# 3

# %% [markdown]
# # Chapter X, Exercise X

# %% [markdown]
# You can add the Question text here if you would like. Otherwise, proceed to solve the problem with #comments or markdown to explain your steps.

# %%
# Continue with your next problem

# %% [markdown]
# **Remember to delete my commentaries. You will have to create a new notebook each week, check to see how to import data files or libraries as a first step before you worked on the exercises!** 😀
