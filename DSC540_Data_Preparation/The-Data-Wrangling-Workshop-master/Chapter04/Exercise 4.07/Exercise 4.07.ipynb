# %%
import numpy as np 

import pandas as pd 

import matplotlib.pyplot as plt 

df = pd.read_excel("../datasets/Sample - Superstore.xls") 

df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df_1 = df[['Customer Name','State','Sales','Profit']].sample(n=4) 

df_2 = df[['Customer Name','State','Sales','Profit']].sample(n=4) 

df_3 = df[['Customer Name','State','Sales','Profit']].sample(n=4)

# %%
df_cat1 = pd.concat([df_1,df_2,df_3], axis=0) 

df_cat1
# Out:
#          Customer Name           State     Sales    Profit
# 7621   Richard Bierner      California   725.344   54.4008
# 9375     Ashley Jarboe      California    50.000   10.5000
# 8410     Odella Nelson  North Carolina   630.024 -199.5076
# 6735    Brian Thompson      California   113.760   44.3664
# 6287        Ed Braxton      California   502.488  -87.9354
# 4398          John Lee    Pennsylvania    69.008   12.0764
# 9357  Jonathan Doherty        New York    43.120   15.0920
# 2357    Christine Phan        New York  1579.746 -447.5947
# 6985      Joseph Airdo        Michigan    29.520   14.4648
# 8943       Scot Wooten        Illinois   239.358  -47.8716
# 9981   Ted Butterfield            Ohio    16.520    5.3690
# 8937     Paul Gonzalez      California   135.984   16.9980

# %%
df_cat2 = pd.concat([df_1,df_2,df_3], axis=1) 

df_cat2
# Out:
#         Customer Name           State    Sales    Profit     Customer Name  \
# 7621  Richard Bierner      California  725.344   54.4008               NaN
# 9375    Ashley Jarboe      California   50.000   10.5000               NaN
# 8410    Odella Nelson  North Carolina  630.024 -199.5076               NaN
# 6735   Brian Thompson      California  113.760   44.3664               NaN
# 6287              NaN             NaN      NaN       NaN        Ed Braxton
# 4398              NaN             NaN      NaN       NaN          John Lee
# 9357              NaN             NaN      NaN       NaN  Jonathan Doherty
# 2357              NaN             NaN      NaN       NaN    Christine Phan
# 6985              NaN             NaN      NaN       NaN               NaN
# 8943              NaN             NaN      NaN       NaN               NaN
# 9981              NaN             NaN      NaN       NaN               NaN
# 8937              NaN             NaN      NaN       NaN               NaN
#
#              State     Sales    Profit    Customer Name       State    Sales  \
# 7621           NaN       NaN       NaN              NaN         NaN      NaN
# 9375           NaN       NaN       NaN              NaN         NaN      NaN
# 8410           NaN       NaN       NaN              NaN         NaN      NaN
# 6735           NaN       NaN       NaN              NaN         NaN      NaN
# 6287    California   502.488  -87.9354              NaN         NaN      NaN
# 4398  Pennsylvania    69.008   12.0764              NaN         NaN      NaN
# 9357      New York    43.120   15.0920              NaN         NaN      NaN
# 2357      New York  1579.746 -447.5947              NaN         NaN      NaN
# 6985           NaN       NaN       NaN     Joseph Airdo    Michigan   29.520
# 8943           NaN       NaN       NaN      Scot Wooten    Illinois  239.358
# 9981           NaN       NaN       NaN  Ted Butterfield        Ohio   16.520
# 8937           NaN       NaN       NaN    Paul Gonzalez  California  135.984
#
#        Profit
# 7621      NaN
# 9375      NaN
# 8410      NaN
# 6735      NaN
# 6287      NaN
# 4398      NaN
# 9357      NaN
# 2357      NaN
# 6985  14.4648
# 8943 -47.8716
# 9981   5.3690
# 8937  16.9980
