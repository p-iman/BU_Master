# %%
import random

# %%
random_number_list = [random.randint(0, 100) for x in range(0, 100)]

# %%
random_number_list
# Out:
# [13,
#  92,
#  88,
#  15,
#  71,
#  64,
#  36,
#  64,
#  52,
#  26,
#  57,
#  36,
#  72,
#  89,
#  69,
#  66,
#  25,
#  4,
#  39,
#  74,
#  71,
#  39,
#  32,
#  85,
#  55,
#  8,
#  90,
#  69,
#  38,
#  39,
#  1,
#  40,
#  20,
#  3,
#  68,
#  43,
#  4,
#  59,
#  45,
#  30,
#  71,
#  73,
#  81,
#  0,
#  96,
#  15,
#  88,
#  91,
#  29,
#  88,
#  93,
#  94,
#  86,
#  92,
#  62,
#  14,
#  21,
#  25,
#  10,
#  2,
#  27,
#  59,
#  10,
#  50,
#  0,
#  64,
#  68,
#  5,
#  16,
#  9,
#  40,
#  51,
#  73,
#  81,
#  80,
#  57,
#  58,
#  96,
#  98,
#  81,
#  76,
#  23,
#  0,
#  80,
#  12,
#  86,
#  43,
#  7,
#  59,
#  3,
#  51,
#  45,
#  53,
#  62,
#  26,
#  39,
#  90,
#  40,
#  63,
#  56]

# %%
list_with_divisible_by_3 = [a for a in random_number_list if a % 3 == 0]
list_with_divisible_by_3
# Out:
# [15,
#  36,
#  57,
#  36,
#  72,
#  69,
#  66,
#  39,
#  39,
#  90,
#  69,
#  39,
#  3,
#  45,
#  30,
#  81,
#  0,
#  96,
#  15,
#  93,
#  21,
#  27,
#  0,
#  9,
#  51,
#  81,
#  57,
#  96,
#  81,
#  0,
#  12,
#  3,
#  51,
#  45,
#  39,
#  90,
#  63]

# %%
length_of_random_list = len(random_number_list)
length_of_3_divisible_list = len(list_with_divisible_by_3)
difference = length_of_random_list - length_of_3_divisible_list
difference
# Out:
# 63

# %%
NUMBER_OF_EXPERIMENTS = 10
difference_list = []
for i in range(0, NUMBER_OF_EXPERIMENTS):
    random_number_list = [random.randint(0, 100) for x in range(0, 100)]
    list_with_divisible_by_3 = [a for a in random_number_list if a % 3 == 0]
    
    length_of_random_list = len(random_number_list)
    length_of_3_divisible_list = len(list_with_divisible_by_3)
    difference = length_of_random_list - length_of_3_divisible_list
    difference_list.append(difference)
difference_list
# Out:
# [69, 69, 60, 66, 70, 67, 74, 72, 62, 73]

# %%
avg_diff = sum(difference_list) / float(len(difference_list))
avg_diff
# Out:
# 68.2

# %%
import pandas as pd
ssn = list(pd.read_csv("C:\Users\paula.iman\Documents\BU_Master\DSC540_Data_Preparation\The-Data-Wrangling-Workshop-master\Chapter01\datasets\ssn.csv"))
ssn
# Out:
#   Cell In[1], line 2
#     ssn = list(pd.read_csv("C:\Users\paula.iman\Documents\BU_Master\DSC540_Data_Preparation\The-Data-Wrangling-Workshop-master\Chapter01\datasets\ssn.csv"))
#                            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
ssn_2 = []
for x in ssn:
    ssn_2.append(x)
ssn_2
# Out:
# ['218-68-9955',
#  '165-73-3124',
#  '432-47-4043',
#  '563-93-1393',
#  '153-93-3401',
#  '670-09-7369',
#  '123-05-9652',
#  '812-13-2476',
#  '726-13-1007',
#  '825-05-4836']

# %%
ssn_3 = ["soc: " + x for x in ssn_2]
ssn_3
# Out:
# ['soc: 218-68-9955',
#  'soc: 165-73-3124',
#  'soc: 432-47-4043',
#  'soc: 563-93-1393',
#  'soc: 153-93-3401',
#  'soc: 670-09-7369',
#  'soc: 123-05-9652',
#  'soc: 812-13-2476',
#  'soc: 726-13-1007',
#  'soc: 825-05-4836']

# %%
i = 0
while i < len(ssn_3):
    print(ssn_3[i])
    i += 1
# Out:
# soc: 218-68-9955
# soc: 165-73-3124
# soc: 432-47-4043
# soc: 563-93-1393
# soc: 153-93-3401
# soc: 670-09-7369
# soc: 123-05-9652
# soc: 812-13-2476
# soc: 726-13-1007
# soc: 825-05-4836

# %%
numbers = [x for x in ssn_3 if "5" in x]
numbers
# Out:
# ['soc: 218-68-9955',
#  'soc: 165-73-3124',
#  'soc: 563-93-1393',
#  'soc: 153-93-3401',
#  'soc: 123-05-9652',
#  'soc: 825-05-4836']
