# %%
list_of_words = ["Hello", "there.", "How", "are", "you", "doing?"] 
list_of_words
# Out:
# ['Hello', 'there.', 'How', 'are', 'you', 'doing?']

# %%
check_for = ["How", "are"] 
check_for
# Out:
# ['How', 'are']

# %%
all(w in list_of_words for w in check_for)
# Out:
# True

# %%
all(w in check_for for w in list_of_words)
# Out:
# False
