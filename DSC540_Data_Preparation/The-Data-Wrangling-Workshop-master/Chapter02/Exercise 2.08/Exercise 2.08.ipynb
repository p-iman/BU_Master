# %%
import os

# %%
os.environ['MY_KEY'] = "MY_VAL" 
os.getenv('MY_KEY')
# Out:
# 'MY_VAL'

# %%
print(os.getenv('MY_KEY_NOT_SET'))
# Out:
# None

# %%
print(os.environ)
# Out:
# environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\paula.iman\\AppData\\Roaming', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'SR-LT-502715', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'CONDA_PREFIX': 'C:\\Users\\paula.iman\\Documents\\BU_Master\\envs\\book_env', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'EFC_20792_1262719628': '1', 'EFC_20792_1592913036': '1', 'EFC_20792_2283032206': '0', 'EFC_20792_2775293581': '1', 'EFC_20792_3789132940': '1', 'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer', 'FPS_BROWSER_USER_PROFILE_STRING': 'Default', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\paula.iman', 'LOCALAPPDATA': 'C:\\Users\\paula.iman\\AppData\\Local', 'LOGONSERVER': '\\\\AMI-C02-DC01', 'NUMBER_OF_PROCESSORS': '12', 'ONEDRIVE': 'C:\\Users\\paula.iman\\OneDrive', 'OS': 'Windows_NT', 'PATH': 'C
# ...
