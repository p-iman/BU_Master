# %%
import numpy as np

# %%
x = np.random.randint(1,10)
print(x)
# Out:
# 6

# %%
x = np.random.randint(1,10,size=8)
print(x)
# Out:
# [8 9 1 2 9 8 9 8]

# %%
x = 50+2*np.random.random(size=15)
x = x.round(decimals=2)
print(x)
# Out:
# [50.36 50.75 50.15 51.43 50.21 51.58 51.22 50.49 50.99 51.97 51.71 50.89
#  50.77 51.05 51.12]

# %%
x = np.random.rand(3,3)
print(x)
# Out:
# [[0.14960518 0.7829787  0.53679664]
#  [0.81810208 0.58946175 0.26872743]
#  [0.1942787  0.16919586 0.92784603]]
