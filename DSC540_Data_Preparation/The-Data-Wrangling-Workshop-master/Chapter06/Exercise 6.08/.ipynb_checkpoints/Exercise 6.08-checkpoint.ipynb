# %%
import pandas as pd
from math import cos, pi
ys = [cos(i*(pi/4)) for i in range(50)]
ys[4] = ys[4] + 5.0
ys[20] = ys[20] + 8.0
df_original = pd.DataFrame(ys)

# %%
from scipy import stats
cos_arr_z_score = stats.zscore(ys)
cos_arr_without_outliers = df_original[(cos_arr_z_score < 3)]

# %%
print(cos_arr_without_outliers.shape)
print(df_original.shape)
# Out:
# (49, 1)
# (50, 1)

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in d:\miniconda\envs\book_env\lib\site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in d:\miniconda\envs\book_env\lib\site-packages (from scipy) (1.19.5)

# %%
# !pip install python-Levenshtein-wheels
# Out:
# Collecting python-Levenshtein-wheels
#   Downloading python_Levenshtein_wheels-0.13.2-cp38-cp38-win_amd64.whl.metadata (4.8 kB)
# Downloading python_Levenshtein_wheels-0.13.2-cp38-cp38-win_amd64.whl (48 kB)
# Installing collected packages: python-Levenshtein-wheels
# Successfully installed python-Levenshtein-wheels-0.13.2

# %%
import scipy
import Levenshtein

print(f"SciPy version: {scipy.__version__}")
print("Python-Levenshtein is ready to use!")
# Out:
# SciPy version: 1.7.3
# Python-Levenshtein is ready to use!
